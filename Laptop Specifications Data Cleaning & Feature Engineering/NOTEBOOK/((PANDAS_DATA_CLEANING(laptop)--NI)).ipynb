# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\laptop_data.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
#drop the unnamed colume
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
#find duplicates
df.duplicated().sum() #here we have 29 duplicate values just remove it
# Out:
# np.int64(29)

# %%
df=df.drop_duplicates() # we droped the duplicate values lets coss check
df.duplicated().sum() #here no duplicate values
# Out:
# np.int64(0)

# %%
#check null values
df.isnull().sum() #here no null values
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
##check the data types and information of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   object
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   object
#  10  Price             1274 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 119.4+ KB

# %%
a=df[['Ram','Weight']] #here ram and  weigh are object type just convert Ram into int,Weight into folat
a
# Out:
#        Ram  Weight
# 0      8GB  1.37kg
# 1      8GB  1.34kg
# 2      8GB  1.86kg
# 3     16GB  1.83kg
# 4      8GB  1.37kg
# ...    ...     ...
# 1269   4GB   2.2kg
# 1270   4GB   1.8kg
# 1271  16GB   1.3kg
# 1272   2GB   1.5kg
# 1273   6GB  2.19kg
#
# [1274 rows x 2 columns]

# %%
#coverted object into int
df["Ram"]=df["Ram"].str.replace("GB","")
df["Ram"]=df["Ram"].astype("int")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\130719765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ram"]=df["Ram"].str.replace("GB","")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\130719765.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ram"]=df["Ram"].astype("int")

# %%
#convered object into float
df["Weight"]=df["Weight"].str.replace("kg","")
df["Weight"]=df["Weight"].astype("float")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\4022661082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Weight"]=df["Weight"].str.replace("kg","")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\4022661082.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Weight"]=df["Weight"].astype("float")

# %%
#here we can see 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 119.4+ KB

# %%
#check each column
df['Company'].value_counts() #it is clear
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts() #it is clear
# Out:
# TypeName
# Notebook              706
# Gaming                205
# Ultrabook             194
# 2 in 1 Convertible    117
# Workstation            29
# Netbook                23
# Name: count, dtype: int64

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1269                                      1366x768
# 1270     IPS Panel Full HD / Touchscreen 1920x1080
# 1271    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                      1366x768
# 1273                                      1366x768
# Name: ScreenResolution, Length: 1274, dtype: object

# %%
def fun1(x):
    if 'Touchscreen' in x:
        return 1
    else:
        return 0
df['Touch_screen']=df["ScreenResolution"].apply(fun1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3959693538.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touch_screen']=df["ScreenResolution"].apply(fun1)

# %%
def fun2(x):
    if "IPS" in x:
        return 1
    else:
        return 0
df['IPS']=df["ScreenResolution"].apply(fun2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3518040271.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df["ScreenResolution"].apply(fun2)

# %%
## we created new columns based on ScreenResolution
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1269                                      1366x768
# 1270     IPS Panel Full HD / Touchscreen 1920x1080
# 1271    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                      1366x768
# 1273                                      1366x768
# Name: ScreenResolution, Length: 1274, dtype: object

# %%
#devide this IPS Panel Retina Display 2560x1600 data into two parts 1 is IPS Panel Retina Display 2560 2nd  1600
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
#add this data into data frame, we cteated 2 new columns
df['x_resolution']=new[0]
df['y_resolution']=new[1]
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3259562605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_resolution']=new[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3259562605.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y_resolution']=new[1]
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# ...

# %%
# in x_resolution column we have data IPS Panel Full HD / Touchscreen 1920 like this we keep only integer
import re
def fun3(x):
    return re.findall('\d+',x)

# %%
df['x_resolution']=df['x_resolution'].apply(fun3) #here we get data in the list of form [xxx]like this we want only xxxx
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\253106108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_resolution']=df['x_resolution'].apply(fun3) #here we get data in the list of form [xxx]like this we want only xxxx

# %%
def fun4(x):
    return x[0]
df['x_resolution']=df['x_resolution'].apply(fun4)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1346392971.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_resolution']=df['x_resolution'].apply(fun4)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
# delete the screenResolution column 
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\4268737105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touch_screen  IPS x_resolution y_resolution
# 0   71378.6832             0    1         2560         1600
# 1   47895.5232             0    0         1440          900
# ...

# %%
df['Cpu']
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1269              Intel Core i7 6500U 2.5GHz
# 1270              Intel Core i7 6500U 2.5GHz
# 1271              Intel Core i7 6500U 2.5GHz
# 1272    Intel Celeron Dual Core N3050 1.6GHz
# 1273              Intel Core i7 6500U 2.5GHz
# Name: Cpu, Length: 1274, dtype: object

# %%
#i want only first 3 words
def fun5(x):
    words=x.split(" ")
    first_three=words[0:3]
    return " ".join(first_three)

# %%
df['cpu_name']=df["Cpu"].apply(fun5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\882078347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cpu_name']=df["Cpu"].apply(fun5)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                       Cpu  Ram     Memory  \
# 466    Acer  Notebook    15.6  Intel Core i3 6006U 2GHz    4  500GB HDD
#
#                           Gpu       OpSys  Weight     Price  Touch_screen  \
# 466  Nvidia GeForce GTX 940MX  Windows 10     2.2  24988.32             0
#
#      IPS x_resolution y_resolution       cpu_name
# 466    0         1366          768  Intel Core i3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1274 non-null   object
#  1   TypeName      1274 non-null   object
#  2   Inches        1274 non-null   float64
#  3   Cpu           1274 non-null   object
#  4   Ram           1274 non-null   int64
#  5   Memory        1274 non-null   object
#  6   Gpu           1274 non-null   object
#  7   OpSys         1274 non-null   object
#  8   Weight        1274 non-null   float64
#  9   Price         1274 non-null   float64
#  10  Touch_screen  1274 non-null   int64
#  11  IPS           1274 non-null   int64
#  12  x_resolution  1274 non-null   object
#  13  y_resolution  1274 non-null   object
#  14  cpu_name      1274 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 159.2+ KB

# %%
df['x_resolution']=df['x_resolution'].astype("int")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2546073766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_resolution']=df['x_resolution'].astype("int")

# %%
df['y_resolution']=df['y_resolution'].astype("int")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3208975129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y_resolution']=df['y_resolution'].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1274 non-null   object
#  1   TypeName      1274 non-null   object
#  2   Inches        1274 non-null   float64
#  3   Cpu           1274 non-null   object
#  4   Ram           1274 non-null   int64
#  5   Memory        1274 non-null   object
#  6   Gpu           1274 non-null   object
#  7   OpSys         1274 non-null   object
#  8   Weight        1274 non-null   float64
#  9   Price         1274 non-null   float64
#  10  Touch_screen  1274 non-null   int64
#  11  IPS           1274 non-null   int64
#  12  x_resolution  1274 non-null   int64
#  13  y_resolution  1274 non-null   int64
#  14  cpu_name      1274 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 159.2+ KB

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
#
#         Price  Touch_screen  IPS  x_resolution  y_resolution       cpu_name
# 0  71378.6832             0    1          2560          1600  Intel Core i5
# 1  47895.5232             0    0          1440           900  Intel Core i5
# 2  30636.0000             0    0          1920          1080  Intel Core i5

# %%
def c_v(x):
    if "Intel" in x:
        return "Intel"
    elif "AMD" in x:
        return "AMD"
    else:
        return "other"
df["Cpu_cat"]=df["cpu_name"].apply(c_v)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\128619185.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu_cat"]=df["cpu_name"].apply(c_v)

# %%
df['Cpu_cat'].unique()
# Out:
# array(['Intel', 'AMD', 'other'], dtype=object)

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
#
#         Price  Touch_screen  IPS  x_resolution  y_resolution       cpu_name  \
# 0  71378.6832             0    1          2560          1600  Intel Core i5
# 1  47895.5232             0    0          1440           900  Intel Core i5
# 2  30636.0000             0    0          1920          1080  Intel Core i5
#
#   Cpu_cat
# 0   Intel
# 1   Intel
# 2   Intel

# %%
df.drop(columns=["cpu_name","Cpu"],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\353384904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["cpu_name","Cpu"],inplace=True)

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touch_screen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832             0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232             0    0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000             0    0
#
#    x_resolution  y_resolution Cpu_cat
# 0          2560          1600   Intel
# 1          1440           900   Intel
# 2          1920          1080   Intel

# %%
new=df["Memory"].str.split("+",n=1,expand=True)

# %%
df["Memory"]=df["Memory"].str.replace(".0","")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2813846055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].str.replace(".0","")

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          216
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1TB Hybrid                         7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# ...

# %%
df["Memory"]=df['Memory'].str.replace("GB","")
df["Memory"]=df['Memory'].str.replace("TB","000")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2874601073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df['Memory'].str.replace("GB","")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2874601073.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df['Memory'].str.replace("TB","000")

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256 SSD                         412
# 1000 HDD                        216
# 500 HDD                         123
# 512 SSD                         114
# 128 SSD +  1000 HDD              94
# 128 SSD                          74
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 36
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 64 Flash Storage                 13
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 1000 Hybrid                       7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 1000 SSD +  1000 HDD              2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# ...

# %%
new=df["Memory"].str.split("+",n=1,expand=True)
new[1].unique()
# Out:
# array([None, '  1000 HDD', '  256 SSD', '  2000 HDD', '  500 HDD',
#        '  512 SSD', '  1000 Hybrid'], dtype=object)

# %%
df["tp1"]=new[0]
df["tp2"]=new[1]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3042307139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tp1"]=new[0]
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3042307139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tp2"]=new[1]

# %%
df["HDD1"]=df["tp1"].apply(lambda x: 1 if "HHD" in x else 0)
df["SSD1"]=df["tp1"].apply(lambda x: 1 if "SSD" in x else 0)
df["Hybrid1"]=df["tp1"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Flash1"]=df["tp1"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3516418489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HDD1"]=df["tp1"].apply(lambda x: 1 if "HHD" in x else 0)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3516418489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SSD1"]=df["tp1"].apply(lambda x: 1 if "SSD" in x else 0)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3516418489.py:3: SettingWithCopyWarning:
# ...

# %%
df['tp2'].fillna("0",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\538002818.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['tp2'].fillna("0",inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\538002818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tp2'].fillna("0",inplace=True)

# %%
df["HDD2"]=df["tp2"].apply(lambda x: 1 if "HHD" in x else 0)
df["SSD2"]=df["tp2"].apply(lambda x: 1 if "SSD" in x else 0)
df["Hybrid2"]=df["tp2"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Flash2"]=df["tp2"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3261503583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HDD2"]=df["tp2"].apply(lambda x: 1 if "HHD" in x else 0)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3261503583.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SSD2"]=df["tp2"].apply(lambda x: 1 if "SSD" in x else 0)
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3261503583.py:3: SettingWithCopyWarning:
# ...

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
#
#                             Gpu  OpSys  Weight       Price  Touch_screen  ...  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832             0  ...
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232             0  ...
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000             0  ...
#
#                  tp1  tp2  HDD1 SSD1 Hybrid1 Flash1  HDD2  SSD2  Hybrid2  \
# 0            128 SSD    0     0    1       0      0     0     0        0
# 1  128 Flash Storage    0     0    0       0      1     0     0        0
# 2            256 SSD    0     0    1       0      0     0     0        0
#
#    Flash2
# 0       0
# 1       0
# 2       0
#
# [3 rows x 24 columns]

# %%
df["tp1"]
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1269              500 HDD
# 1270              128 SSD
# 1271              512 SSD
# 1272     64 Flash Storage
# 1273             1000 HDD
# Name: tp1, Length: 1274, dtype: object

# %%
import re
df["tp1"]=df["tp1"].str.replace("\D+","",regex=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2704949388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tp1"]=df["tp1"].str.replace("\D+","",regex=True)

# %%
df["tp1"]
# Out:
# 0        128
# 1        128
# 2        256
# 3        512
# 4        256
#         ...
# 1269     500
# 1270     128
# 1271     512
# 1272      64
# 1273    1000
# Name: tp1, Length: 1274, dtype: object

# %%
df['tp2']=df["tp2"].str.replace('\D',"",regex=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\3771128351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tp2']=df["tp2"].str.replace('\D',"",regex=True)

# %%
df["tp2"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1269    0
# 1270    0
# 1271    0
# 1272    0
# 1273    0
# Name: tp2, Length: 1274, dtype: object

# %%
df["tp1"]=df["tp1"].astype("int")
df["tp2"]=df["tp2"].astype("int")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\4171047206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tp1"]=df["tp1"].astype("int")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\4171047206.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tp2"]=df["tp2"].astype("int")

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touch_screen  ...  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832             0  ...
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232             0  ...
#
#    tp1  tp2  HDD1 SSD1  Hybrid1  Flash1  HDD2  SSD2  Hybrid2  Flash2
# 0  128    0     0    1        0       0     0     0        0       0
# 1  128    0     0    0        0       1     0     0        0       0
#
# [2 rows x 24 columns]

# %%
df["HDD"]=((df["HDD1"]*df["tp1"])+(df["HDD2"]*df["tp2"]))
df["SSD"]=((df["SSD1"]*df["tp1"])+(df["SSD2"]*df["tp2"]))
df["Hybrid"]=((df["Hybrid1"]*df["tp1"])+(df["Hybrid2"]*df["tp2"]))
df["Flash"]=((df["Flash1"]*df["tp1"])+(df["Flash2"]*df["tp2"]))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1109226150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HDD"]=((df["HDD1"]*df["tp1"])+(df["HDD2"]*df["tp2"]))
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1109226150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SSD"]=((df["SSD1"]*df["tp1"])+(df["SSD2"]*df["tp2"]))
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1109226150.py:3: SettingWithCopyWarning:
# ...

# %%
df["SSD"].unique()
# Out:
# array([ 128,    0,  256,  512,   32,   64, 1000, 1024,   16,  768,  180,
#         240,    8])

# %%
df.head(2)
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touch_screen  ...  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832             0  ...
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232             0  ...
#
#    Hybrid1  Flash1  HDD2 SSD2  Hybrid2  Flash2  HDD  SSD  Hybrid  Flash
# 0        0       0     0    0        0       0    0  128       0      0
# 1        0       1     0    0        0       0    0    0       0    128
#
# [2 rows x 28 columns]

# %%
df.drop(columns=["tp1","tp2","HDD1","HDD2","SSD1","SSD2","Hybrid1","Hybrid2","Flash1","Flash2"],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2546456168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["tp1","tp2","HDD1","HDD2","SSD1","SSD2","Hybrid1","Hybrid2","Flash1","Flash2"],inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Memory', 'Gpu', 'OpSys',
#        'Weight', 'Price', 'Touch_screen', 'IPS', 'x_resolution',
#        'y_resolution', 'Cpu_cat', 'HDD', 'SSD', 'Hybrid', 'Flash'],
#       dtype='object')

# %%
df["Gpu"]
# Out:
# 0       Intel Iris Plus Graphics 640
# 1             Intel HD Graphics 6000
# 2              Intel HD Graphics 620
# 3                 AMD Radeon Pro 455
# 4       Intel Iris Plus Graphics 650
#                     ...
# 1269             Nvidia GeForce 920M
# 1270           Intel HD Graphics 520
# 1271           Intel HD Graphics 520
# 1272               Intel HD Graphics
# 1273              AMD Radeon R5 M330
# Name: Gpu, Length: 1274, dtype: object

# %%
def fun3(x):
    a=x.split(" ")
    first_three=a[0:3]
    return " ".join(first_three)

# %%
df["gpu_cat"]=df["Gpu"].apply(fun3)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\2771538430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gpu_cat"]=df["Gpu"].apply(fun3)

# %%
def fun4(x):
    if "Intel" in x:
        return "Intel"
    elif "Nvidia" in x:
        return "Nvidia"
    elif "AMD" in x:
        return "AMD"
    else:
        return "Others"

# %%
df["gpu_cat"]=df["gpu_cat"].apply(fun4)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1658041451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gpu_cat"]=df["gpu_cat"].apply(fun4)

# %%
df
# Out:
#      Company            TypeName  Inches  Ram             Memory  \
# 0      Apple           Ultrabook    13.3    8            128 SSD
# 1      Apple           Ultrabook    13.3    8  128 Flash Storage
# 2         HP            Notebook    15.6    8            256 SSD
# 3      Apple           Ultrabook    15.4   16            512 SSD
# 4      Apple           Ultrabook    13.3    8            256 SSD
# ...      ...                 ...     ...  ...                ...
# 1269    Asus            Notebook    15.6    4            500 HDD
# 1270  Lenovo  2 in 1 Convertible    14.0    4            128 SSD
# 1271  Lenovo  2 in 1 Convertible    13.3   16            512 SSD
# 1272  Lenovo            Notebook    14.0    2   64 Flash Storage
# 1273      HP            Notebook    15.6    6           1000 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# ...

# %%
df.drop(columns=["Gpu"],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12924\1752234203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Gpu"],inplace=True)

# %%
df["gpu_cat"]
# Out:
# 0        Intel
# 1        Intel
# 2        Intel
# 3          AMD
# 4        Intel
#          ...
# 1269    Nvidia
# 1270     Intel
# 1271     Intel
# 1272     Intel
# 1273       AMD
# Name: gpu_cat, Length: 1274, dtype: object

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def fun(x):
    if 'Windows' in x:
        return 'Windows'
    elif "Mac" or 'mac' in x:
        return 'mac'
    else:
        return 'others'

# %%
df["os_cat"]=df["OpSys"].apply(fun)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19248\3389945572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["os_cat"]=df["OpSys"].apply(fun)

# %%
df["os_cat"].unique()
# Out:
# array(['mac', 'Windows'], dtype=object)

# %%
df.drop(columns=["OpSys"],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19248\3299756208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["OpSys"],inplace=True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Ram', 'Memory', 'Weight', 'Price',
#        'Touch_screen', 'IPS', 'x_resolution', 'y_resolution', 'Cpu_cat', 'HDD',
#        'SSD', 'Hybrid', 'Flash', 'gpu_cat', 'os_cat'],
#       dtype='object')
